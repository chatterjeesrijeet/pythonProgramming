# %% [markdown]
# ### Declaration and basic operations

# %%
mylist = [1,2,1,5]

# %%
type(mylist)
# Out:
# list

# %%
len(mylist)
# Out:
# 4

# %%
mylist.append(5)

# %%
mylist
# Out:
# [1, 2, 1, 5, 5]

# %%
mylist.extend([8,9,10])

# %%
mylist
# Out:
# [1, 2, 1, 5, 5, 8, 9, 10]

# %%
mylist.insert(19,23)

# %% [markdown]
#      Insert at index,val does not throw error, if the index is out of range it will add in the end.

# %%
mylist
# Out:
# [1, 2, 1, 5, 5, 8, 9, 10, 23]

# %%
mylist.pop()
# Out:
# 23

# %% [markdown]
#     Pop() popps the last element in the list bydefault but you can pass an index value as well, incase the index value is outside it throws eror

# %%
mylist.pop(90)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-d0aaefa8cb89> in <module>
# ----> 1 mylist.pop(90)
#
# IndexError: pop index out of range

# %% [markdown]
# ### Address of Variables vs List : Mutability and Immutability

# %% [markdown]
#       By-default Lists will not point to the same address even if they are same !!!

# %%
a = [20,20,30] 
b = [20,20,30]
print(id(a))
print(id(b))
# Out:
# 140667374776384
# 140667374740544

# %% [markdown]
#     If made to point to the same address ... Making changes in every will refect in every list

# %%
a = [20,20,30] 
b = a
print(id(a))
print(id(b))
b[0] = 13
print(id(a))
print(id(b))
# Out:
# 140667374436608
# 140667374436608
# 140667374436608
# 140667374436608

# %%
print("a : ",a)
print("b : ",b)
# Out:
# a :  [13, 20, 30]
# b :  [13, 20, 30]

# %% [markdown]
#     But when you delete one of them the other keep pointing to the same address and wont throw any error

# %%
del a
print("id of b : ",id(b))
print("b : ",b)
# Out:
# id of b :  140667374436608
# b :  [13, 20, 30]

# %% [markdown]
#     The behaviour in case of variables is different, val range -5 to 265 bydefault they will point to the same address

# %%
a = 20 
b = 20

print(id(a))
print(id(b))

a = -20 
b = -20

print(id(a))
print(id(b))
# Out:
# 4506049824
# 4506049824
# 140667374754480
# 140667374754864

# %% [raw]
# If by they are referring to same address
#       (a) Due to default nature :
#       (b) Forcefully :
#
#          You update any one of them , it creates a separate reference for the other

# %%
a = 20 
b = 20 
print(id(a))
print(id(b))
a = 13
print(id(a))
print(id(b))
# Out:
# 4506049824
# 4506049824
# 4506049600
# 4506049824

# %%
a = -345
b = a
print(id(a))
print(id(b),'\n')

#Now lets us change a or b  and then print their ids  
a = 13
print("After modifying a variable a or b \n")
print(id(a))
print(id(b))

#'''It should print two different address'''
# Out:
# 140667374754128
# 140667374754128
#
# After modifying a variable a or b
#
# 4506049600
# 140667374754128

# %% [markdown]
#       Infact when you chage a variable it does not update teh value at teh same location ..it basically create a new address

# %%
a = 12
print(id(a))
a = 13 
print(id(a))
# Out:
# 4506049568
# 4506049600

# %%
# Variables 
a = -199
print(f"address of a :                {id(a)}")

def f(var):
    print(f"address of var received :     {id(var)}")
    var += 100
    print(f"address of var after update : {id(var)}")
    print("Local Var : ",var)
    
f(a)
print("Global a : ",a)
# Out:
# address of a :                140667374754608
# address of var received :     140667374754608
# address of var after update : 140667374755120
# Local Var :  -99
# Global a :  -199

# %% [markdown]
# ### Shallow Copy

# %%
a = [1,2]
b = a
print(id(a))
print(id(b))
# Out:
# 140667374514368
# 140667374514368

# %%
a[0] = 8 
print(a)
print(b)
# Out:
# [8, 2]
# [8, 2]

# %% [markdown]
# ### Deep Copy

# %%
a = [1,2]
b = [x for x in a]

print(id(a))
print(id(b))
# Out:
# 140667374508352
# 140667374506752

# %%
a[0] = 8 
print(a)
print(b)
# Out:
# [8, 2]
# [1, 2]

# %% [markdown]
#                         Things are ok if its simple element sfor for composite elements you have to ensure
#                         that every level you are coping like that only

# %% [markdown]
# ### With 2 D Lists  : deep Copy

# %%
a = [[1,2],4,5]
b = [x for x in a]

print(id(a))
print(id(b))
# Out:
# 140667376813888
# 140667376813312

# %%
a[1] = 8 
print(a)
print(b)
# Out:
# [[1, 2], 8, 5]
# [[1, 2], 4, 5]

# %% [markdown]
# ### Cloning or Copying a list :
#
#      1. https://www.geeksforgeeks.org/python-cloning-copying-list/
#      2. https://www.geeksforgeeks.org/copy-python-deep-copy-shallow-copy/

# %%
l1 = [1,2,3]
l2 = l1 
print(id(l1))
print(id(l2))

print('\n')

l3 = [3,4,5]
l4 = l3[:]
print(id(l3))
print(id(l4))

print('\n')

l5 = [3,4,5]
l6 = list(l5)
print(id(l5))
print(id(l6))
# Out:
# 140667376883392
# 140667376883392
#
#
# 140667376883200
# 140667376883776
#
#
# 140667376851712
# 140667376852096

# %%
import copy
L1 = [12,3,56,24,'srijeet']
L2 = copy.copy(L1)

print(id(L1),id(L2))
print(f"L1 : {L1} ")
print(f"L2 : {L2} ")

L2[0] = 23

print(id(L1),id(L2))
print(f"L1 : {L1} ")
print(f"L2 : {L2} ")
# Out:
# 140667374509632 140667374438976
# L1 : [12, 3, 56, 24, 'srijeet']
# L2 : [12, 3, 56, 24, 'srijeet']
# 140667374509632 140667374438976
# L1 : [12, 3, 56, 24, 'srijeet']
# L2 : [23, 3, 56, 24, 'srijeet']

# %%
'''1. using [:] '''

L1 = [[11,13],27,71]
L2 = L1[:]
L2[0].append(-99)
print("\nUsing [:] approach : ",L1)

'''2. Using list() method''' 

L1 = [[11,13],27,71]
L2 = list(L1)
L2[0].append(-99)
print("\nUsing list() method : ",L1)

'''3. Using  extend() method'''

L1 = [[11,13],27,71]
L2 = []
L2.extend(L1)
L2[0].append(-99)
print("\nUsing  extend() method : ", L1)

'''4. Using List Comprehension'''

L1 = [[11,13],27,71]
L2 = [x for x in L1]
L2.extend(L1)
L2[0].append(-99)
print("\nUsing List Comprehension",L1)


'''5. Using copy() method '''

L1 = [[11,13],27,71]
L2 = L1.copy()
L2[0].append(-99)
print("\nUsing copy() method : ",L1)

'''6. Using shallow copy '''
import copy
L1 = [[11,13],27,71]
L2 = copy.copy(L1)
L2[0].append(-99)
print("\nUsing shallow copy : ",L1)

'''7. using deepcopy'''
import copy
L1 = [[11,13],27,71]
L2 = copy.deepcopy(L1)
L2[0].append(-99)
print("\n--------------------------------------------------------------")
print("\n\nUsing deepcopy : ",L1)
# Out:
# Using [:] approach :  [[11, 13, -99], 27, 71]
#
# Using list() method :  [[11, 13, -99], 27, 71]
#
# Using  extend() method :  [[11, 13, -99], 27, 71]
#
# Using List Comprehension [[11, 13, -99], 27, 71]
#
# Using copy() method :  [[11, 13, -99], 27, 71]
#
# Using shallow copy :  [[11, 13, -99], 27, 71]
#
# --------------------------------------------------------------
#
#
# Using deepcopy :  [[11, 13], 27, 71]

# %% [markdown]
#     Deep Copy is equivalent to the below code : You have to copy each item one by one and that way the composite items are also copied and not just their ref

# %%
L1 = [[11,13],[27],[71]]
n = len(L1)
L2 = []

print(f"address of L1[0] : {id(L1[0])}")
print(f"address of L1[0][0] : {id(L1[0][0])}")

for i in range(n):
    L2.append(list(L1[i]))

print('\n')
print(f"address of L2[0] : {id(L2[0])}")
print(f"address of L2[0][0] : {id(L2[0][0])}")

L2[0].append(-99)

print('\n')
print("L1 : ",L1)
print("L2 : ", L2)
# Out:
# address of L1[0] : 140667376774016
# address of L1[0][0] : 4506049536
#
#
# address of L2[0] : 140667376797376
# address of L2[0][0] : 4506049536
#
#
# L1 :  [[11, 13], [27], [71]]
# L2 :  [[11, 13, -99], [27], [71]]

# %% [markdown]
# ### Deep Copy vs Shallow Copy
#          --- copy.deepcopy(List1)
#          --- copy.copy(List1)

# %% [markdown]
# The difference between shallow and deep copying is only relevant for compound objects (objects that contain other objects, like lists or class instances):

# %%
print("\n------------------------------ This is for NON COMPUND OBJECTS --------------------------------\n\n")
L1 = [[1,2],10,20,'srijeet']
L2 = L1[:]

print("------ Before update in L2[1] ------\n")
print(f"Address of L1[0] : {id(L1[1])}")
print(f"Address of L2[0] : {id(L2[1])}\n")

L2[1] = 999

print("------ After update in L2[1]------\n")
print(f"Address of L1[0] : {id(L1[1])}")
print(f"Address of L2[0] : {id(L2[1])}\n")

print(''' Conclusion : See after update in L2[1], which is non compunf element, now L1[1] and L2[1] references to two different locations,
                       This means that the changes in L2 WILL NOT be REFLECTED in L1 !!! 
          ''')

print("\n\n------------------------------ Now for COMPOUND OBJECTS --------------------------------\n\n")

print("------ Before update in L2[0][0]------\n")
print(f"Address of L1[0]  : {id(L1[0])}")
print(f"Address of L2[0]  : {id(L2[0])}")

print(f"  Address of L1[0][0]  : {id(L1[0][0])}")
print(f"  Address of L2[0][0]  : {id(L2[0][0])}\n")

L2[0][0] = 9999

print("------ After update in L2[0][0]------\n")
print(f"Address of L1[0] : {id(L1[0])}")
print(f"Address of L2[0] : {id(L2[0])}")

print(f"  Address of L1[0][0] : {id(L1[0][0])}")
print(f"  Address of L2[0][0] : {id(L2[0][0])}\n")

print(''' Conclusion : After update in L2 now L1[0] and L2[0] references to the same locations,
          This means that the changes in L2 WILL BE REFLECTED in L1 !!! 
          ''')
# Out:
# ------------------------------ This is for NON COMPUND OBJECTS --------------------------------
#
#
# ------ Before update in L2[1] ------
#
# Address of L1[0] : 4506049504
# Address of L2[0] : 4506049504
#
# ------ After update in L2[1]------
#
# Address of L1[0] : 4506049504
# Address of L2[0] : 140667374754928
#
#  Conclusion : See after update in L2[1], which is non compunf element, now L1[1] and L2[1] references to two different locations,
#                        This means that the changes in L2 WILL NOT be REFLECTED in L1 !!!
#
#
#
# ------------------------------ Now for COMPOUND OBJECTS --------------------------------
#
#
# ------ Before update in L2[0][0]------
#
# Address of L1[0]  : 140667374982976
# Address of L2[0]  : 140667374982976
#   Address of L1[0][0]  : 4506049216
#   Address of L2[0][0]  : 4506049216
#
# ------ After update in L2[0][0]------
#
# Address of L1[0] : 140667374982976
# Address of L2[0] : 140667374982976
#   Address of L1[0][0] : 140667374755504
#   Address of L2[0][0] : 140667374755504
#
#  Conclusion : After update in L2 now L1[0] and L2[0] references to the same locations,
#           This means that the changes in L2 WILL BE REFLECTED in L1 !!!

# %% [markdown]
# ![Screenshot%202021-09-11%20at%205.14.04%20PM.png](attachment:Screenshot%202021-09-11%20at%205.14.04%20PM.png)
